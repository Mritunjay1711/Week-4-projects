# %% [markdown]
# <a href="https://colab.research.google.com/github/Mritunjay1711/Week-4-projects/blob/main/Sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
image = cv2.imread("_DSC0089.JPG")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
plt.imshow(image_gray, cmap = 'gray')

# %%
image_gray_inv = cv2.bitwise_not(image_gray)
plt.imshow(image_gray_inv, cmap = 'gray')

# %%
image_gray_inv_blur = cv2.blur(image_gray_inv, (420, 420))
plt.imshow(image_gray_inv_blur, cmap = 'gray')

# %%
image_gray_inv_blur_divide = cv2.divide(image_gray_inv_blur, image_gray_inv, scale = 256)
plt.imshow(image_gray_inv_blur_divide, cmap = 'gray')
