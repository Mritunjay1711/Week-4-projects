# %% [markdown]
# <a href="https://colab.research.google.com/github/Mritunjay1711/Week-4-projects/blob/main/BackgroundChange.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown --id 1yhGmBvOADs1Qzry8clonWlepbGkOj-PO
# !unzip week4_assets.zip -d .
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1yhGmBvOADs1Qzry8clonWlepbGkOj-PO
# To: /content/week4_assets.zip
# 100% 256k/256k [00:00<00:00, 37.5MB/s]
# Archive:  week4_assets.zip
#   inflating: ./bg2.jpg
#   inflating: ./humans.jpg
#   inflating: ./logo.png
#   inflating: ./person.jpg
#   inflating: ./pizza_bluescreen.jpg

# %% [markdown]
# #Background Change

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
img = cv2. imread("pizza_bluescreen.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
bg = cv2.imread("bg2.jpg")
bg = cv2.cvtColor(bg, cv2.COLOR_BGR2RGB)
plt.imshow(bg)

# %%
upper_blue = (20, 40, 255)
lower_blue = (0, 0, 0)

mask = cv2.inRange(img, lower_blue, upper_blue)

# %%
plt.imshow(mask, cmap = 'gray')

# %%
bg = cv2.resize(bg, (img.shape[1], img.shape[0]))

bg.shape, img.shape
# Out:
# ((514, 816, 3), (514, 816, 3))

# %%
b = cv2.bitwise_and(bg, bg, mask = mask)
a = cv2.bitwise_and(img, img, mask =~ mask)

plt.imshow(b)
plt.show()
plt.imshow(a)
plt.show


final_image = cv2.add(a, b)
plt.imshow(final_image)
plt.show
# Out:
# <function matplotlib.pyplot.show>
